# %%
import matplotlib.pyplot as plt

# %%
# y축 데이터로 그리기
# 리스트 데이터로 그리기
data=[1,3,5,9,7]
plt.plot(data)

# %%
# 시리즈 데이터로 그리기
import pandas as pd
s=pd.Series([1,3,5,9,7])
# 그래프 그리기
plt.plot(s)

# %%
# 인덱스 변경하기
ss=pd.Series([1,3,5,9,7],index=[10,20,30,40,50])
plt.plot(ss)

# %%
# 문자 인덱스로 변경하기
sss=pd.Series([1,3,5,7,9], index=['a','b','c','d','e'])
plt.plot(sss)

# %%
# x축, y축 데이터로 그리기
x=[1,5,6,9,10]
y=[1,5,3,9,7]
plt.plot(x,y)

# %%
# 데이터프레임 데이터로 그리기
sss=pd.DataFrame({'x':[1,5,6,9,10],'y':[1,5,3,9,7]})
sss
# Out:
#     x  y
# 0   1  1
# 1   5  5
# 2   6  3
# 3   9  9
# 4  10  7

# %%
# 그래프 그리기
x=sss['x']
y=sss['y']
plt.plot(x,y)

# %%
# 시리즈 데이터로 그리기
s=pd.Series([1,5,3,9,7])
s
plt.plot(s)
plt.show()

# %%
plt.plot(s.index, s.values)
plt.show()
